# %% [markdown]
# # Data Exploration and Preparation for Coursera Dashboard

# %% [markdown]
# ### Load CSV and Preview First 5 Rows

# %%
# Import the pandas library for data manipulation

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Load the CSV file into a DataFrame
path="C:/Users/SANDRINE/Downloads/Cousera Courses Metadata for Analytics 2025/archive/courses_en.csv"
df=pd.read_csv(path)
# Display the first 5 rows to check the data
df.head()
# Out:
#                                                  url  \
# 0   https://www.coursera.org/learn/-network-security
# 1  https://www.coursera.org/learn/-security-princ...
# 2  https://www.coursera.org/learn/21st-century-en...
# 3  https://www.coursera.org/learn/360-vr-video-pr...
# 4  https://www.coursera.org/learn/3d-anatomy-phys...
#
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                            category  \
# 0            Information Technology
# 1            Information Technology
# 2  Physical Science And Engineering
# 3               Arts And Humanities
# 4                            Health
#
#                                       what_you_learn  \
# 0                                                NaN
# 1                                                NaN
# 2  Understand the complexity of systems supplying...
# 3                                                NaN
# 4  Learners will understand how body structure su...
#
#                                               skills language  \
# 0  Computer Networking, Network Planning And Desi...  English
# 1  Cyber Security Policies, Data Integrity, Cyber...  English
# 2  Electric Power Systems, Environmental Policy, ...  English
# 3  Virtual Reality, Videography, Media Production...  English
# 4  Vital Signs, Basic Patient Care, Anatomy, Heal...  English
#
#                                          instructors  \
# 0                                      ['~31081695']
# 1                                      ['~31081695']
# 2                                     ['brad-hayes']
# 3                                     ['googlearvr']
# 4  ['~167016541', '~166856472', '~166856442', '~1...
#
#                                              content
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...
# 3  Welcome to the Google AR & VR Virtual Reality ...
# 4  This course provides a foundational understand...

# %% [markdown]
# ### Exploration of the Coursera Courses Metadata dataset

# %%
# Display general information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5411 entries, 0 to 5410
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             5411 non-null   object
#  1   name            5411 non-null   object
#  2   category        5411 non-null   object
#  3   what_you_learn  3005 non-null   object
#  4   skills          5411 non-null   object
#  5   language        5411 non-null   object
#  6   instructors     5411 non-null   object
#  7   content         5411 non-null   object
# dtypes: object(8)
# memory usage: 338.3+ KB

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# url                  0
# name                 0
# category             0
# what_you_learn    2406
# skills               0
# language             0
# instructors          0
# content              0
# dtype: int64

# %%
# Count unique values for each column 
df.nunique()
# Out:
# url               5411
# name              5370
# category            11
# what_you_learn    2979
# skills            5408
# language             1
# instructors       2593
# content           5380
# dtype: int64

# %%
# Show a random sample of 5 rows to inspect data variety
df.sample(5)
# Out:
#                                                     url  \
# 3231  https://www.coursera.org/learn/mandarin-chinese-1
# 874   https://www.coursera.org/learn/clinicalsimulat...
# 5248      https://www.coursera.org/learn/virtual-school
# 3085  https://www.coursera.org/learn/lesson-small-ta...
# 3545        https://www.coursera.org/learn/neurobiology
#
#                                                    name           category  \
# 3231          Mandarin Chinese 1: Chinese for Beginners  Language Learning
# 874   Essentials in Clinical Simulations Across the ...             Health
# 5248                 Foundations of Virtual Instruction    Social Sciences
# 3085    Lesson | Small Talk & Conversational Vocabulary  Language Learning
# 3545  Understanding the Brain: The Neurobiology of E...             Health
#
#      what_you_learn                                             skills  \
# 3231            NaN  Oral Comprehension, Cultural Sensitivity, Gram...
# 874             NaN  Patient Education And Counseling, Clinical Ass...
# 5248            NaN  Learning Management Systems, End User Training...
# 3085            NaN  Interpersonal Communications, Communication, V...
# 3545            NaN  Coordination, Communication Systems, Biology, ...
#
#      language                                        instructors  \
# 3231  English                               ['wangjun', 'an-na']
# 874   English  ['kristina-dreifuerst', 'crystel-farina', 'pam...
# 5248  English                                         ['cindyc']
# 3085  English                                ['amaliabstephens']
# 3545  English                                       ['~4454153']
#
#                                                 content
# 3231  Mandarin Chinese 1: Chinese for beginners is a...
# 874   This 7-week course provides you with key strat...
# 5248  Welcome to Foundations of Virtual Instruction!...
# 3085  This lesson is part of a full course, Speak En...
# 3545  Learn how the nervous system produces behavior...

# %% [markdown]
# ## Exploding the 'Skills' Column
#
# In this step, we will **explode the 'skills' column** so that each row corresponds to **a single skill**.
# The original 'skills' column contains multiple skills separated by commas for each course.

# %%
# Split the 'skills' string into a list using comma as separator
df['skills'] = df['skills'].str.split(',')

# Create one row per skill
df = df.explode('skills')

# Remove extra spaces around each skill
df['skills'] =df['skills'].str.strip()

# Remove empty strings 
df = df[df['skills'] != '']
# Display the 5first rows
df.head()
# Out:
#                                                 url              name  \
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
#
#                  category what_you_learn                       skills  \
# 0  Information Technology            NaN          Computer Networking
# 0  Information Technology            NaN  Network Planning And Design
# 0  Information Technology            NaN                       TCP/IP
# 0  Information Technology            NaN             Threat Detection
# 0  Information Technology            NaN                Cyber Attacks
#
#   language    instructors                                            content
# 0  English  ['~31081695']  Welcome to course 4 of 5 of this Specializatio...
# 0  English  ['~31081695']  Welcome to course 4 of 5 of this Specializatio...
# 0  English  ['~31081695']  Welcome to course 4 of 5 of this Specializatio...
# 0  English  ['~31081695']  Welcome to course 4 of 5 of this Specializatio...
# 0  English  ['~31081695']  Welcome to course 4 of 5 of this Specializatio...

# %% [markdown]
# ###  Cleaning and Exploding the `instructors` Column
#
# The `instructors` column contains one or several instructor identifiers per course.
#
# 1. **Remove the `~` prefix** from instructor identifiers.
# 2. **Split** values into a list when multiple instructors are present.
# 3. **Explode** the column so each instructor appears on a separate row.
# 4. **Trim spaces** for clean and consistent formatting.
# 5. **Remove empty values** after cleaning.

# %%
#Cleaning and exploding the 'instructors' column

# 1. Remove the "~" prefix
df['instructors'] = df['instructors'].str.replace('~', '', regex=False)

# 2. Remove brackets [] and quotes '  (in case the values look like lists)
df['instructors'] = df['instructors'].str.replace(r"[\[\]']", "", regex=True)

# 3. Split multiple instructors into a list (comma-separated)
df['instructors'] = df['instructors'].str.split(',')

# 4. Explode the list
df_instructors = df.explode('instructors')

# 5. Remove leading/trailing spaces
df_instructors['instructors'] = df_instructors['instructors'].str.strip()

# 6. Remove empty values
df_instructors = df_instructors[df_instructors['instructors'] != ""]
df=df_instructors
# Show head
df.head()
# Out:
#                                                 url              name  \
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
# 0  https://www.coursera.org/learn/-network-security  Network Security
#
#                  category what_you_learn                       skills  \
# 0  Information Technology            NaN          Computer Networking
# 0  Information Technology            NaN  Network Planning And Design
# 0  Information Technology            NaN                       TCP/IP
# 0  Information Technology            NaN             Threat Detection
# 0  Information Technology            NaN                Cyber Attacks
#
#   language instructors                                            content
# 0  English    31081695  Welcome to course 4 of 5 of this Specializatio...
# 0  English    31081695  Welcome to course 4 of 5 of this Specializatio...
# 0  English    31081695  Welcome to course 4 of 5 of this Specializatio...
# 0  English    31081695  Welcome to course 4 of 5 of this Specializatio...
# 0  English    31081695  Welcome to course 4 of 5 of this Specializatio...

# %%
# Grouping by course (url)
df_summary = df.groupby('url').agg(
    name=('name', 'first'),  # keep the course name
    category=('category', 'first'),  # keep the category
    language=('language', 'first'),  # keep the language
    num_unique_skills=('skills', 'nunique'),  # count unique skills
    num_unique_instructors=('instructors', 'nunique'),  # count unique instructors
    what_you_learn=('what_you_learn', 'first'),  # keep 'what you will learn' as is for now
    content=('content', 'first')  # keep the content as is
).reset_index()

# Display the first rows of the summarized dataframe
df_summary.head()
# Out:
#                                                  url  \
# 0   https://www.coursera.org/learn/-network-security
# 1  https://www.coursera.org/learn/-security-princ...
# 2  https://www.coursera.org/learn/21st-century-en...
# 3  https://www.coursera.org/learn/360-vr-video-pr...
# 4  https://www.coursera.org/learn/3d-anatomy-phys...
#
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                            category language  num_unique_skills  \
# 0            Information Technology  English                 15
# 1            Information Technology  English                 11
# 2  Physical Science And Engineering  English                 14
# 3               Arts And Humanities  English                  9
# 4                            Health  English                 11
#
#    num_unique_instructors                                     what_you_learn  \
# 0                       1                                               None
# 1                       1                                               None
# 2                       1  Understand the complexity of systems supplying...
# 3                       1                                               None
# 4                       4  Learners will understand how body structure su...
#
#                                              content
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...
# 3  Welcome to the Google AR & VR Virtual Reality ...
# 4  This course provides a foundational understand...

# %%
df_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5411 entries, 0 to 5410
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   url                     5411 non-null   object
#  1   name                    5411 non-null   object
#  2   category                5411 non-null   object
#  3   language                5411 non-null   object
#  4   num_unique_skills       5411 non-null   int64
#  5   num_unique_instructors  5411 non-null   int64
#  6   what_you_learn          3005 non-null   object
#  7   content                 5411 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 338.3+ KB

# %%
df_skills = df[['url', 'skills']]

df_skills.head()
# Out:
#                                                 url  \
# 0  https://www.coursera.org/learn/-network-security
# 0  https://www.coursera.org/learn/-network-security
# 0  https://www.coursera.org/learn/-network-security
# 0  https://www.coursera.org/learn/-network-security
# 0  https://www.coursera.org/learn/-network-security
#
#                         skills
# 0          Computer Networking
# 0  Network Planning And Design
# 0                       TCP/IP
# 0             Threat Detection
# 0                Cyber Attacks

# %%
df_instructors = df[['url', 'instructors']]
df_instructors.head()
# Out:
#                                                 url instructors
# 0  https://www.coursera.org/learn/-network-security    31081695
# 0  https://www.coursera.org/learn/-network-security    31081695
# 0  https://www.coursera.org/learn/-network-security    31081695
# 0  https://www.coursera.org/learn/-network-security    31081695
# 0  https://www.coursera.org/learn/-network-security    31081695

# %%
df_summary.to_csv("coursera_data.csv" , index=False)
df_skills.to_csv("coursera_skills.csv" , index=False)
df_instructors.to_csv("coursera_instructors.csv", index=False)
